# %%
import pandas as pd
import joblib
import lightgbm as lgb
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import f1_score

# Đọc dữ liệu
def load_data(train_path, test_path):
    train_dt = pd.read_csv(train_path)
    test_dt = pd.read_csv(test_path)
    return train_dt, test_dt

train_dt, test_dt = load_data('cityu10c_train_dataset.csv', 'cityu10c_test_dataset.csv')

# Hiển thị thông tin dữ liệu
print(train_dt.info())
print(train_dt.describe())
print(test_dt.info())
print(test_dt.describe())

# Xử lý dữ liệu thiếu và loại bỏ cột không cần thiết
def preprocess_missing_values(df):
    df = df.copy()
    df.drop(columns=['ApplicationDate'], inplace=True, errors='ignore')
    return df

# Lấy danh sách các cột phân loại có ít giá trị duy nhất
def get_categorical_candidates(df, threshold=15):
    unique_counts = df.nunique()
    categorical_candidates = unique_counts[unique_counts < threshold].index.tolist()
    return [col for col in categorical_candidates if col != 'ID']

# Xử lý dữ liệu
train_dt = preprocess_missing_values(train_dt)
train_target = train_dt.pop('LoanApproved')
test_dt = preprocess_missing_values(test_dt)

categorical_candidates = get_categorical_candidates(train_dt)
numerical_candidates = [col for col in train_dt.columns if col not in categorical_candidates]

# Transformers
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(drop='first', handle_unknown='ignore'))
])

numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('scaler', StandardScaler())
])

# ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_candidates),
        ('cat', categorical_transformer, categorical_candidates)
    ]
)

# Tạo pipeline với LightGBM
pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', lgb.LGBMClassifier())
])

# Tách tập train và validation
X_train, X_val, y_train, y_val = train_test_split(train_dt, train_target, test_size=0.2, random_state=42)

# Thiết lập tham số cho GridSearch
param_grid = {
    'classifier__num_leaves': [31],
    'classifier__min_data_in_leaf': [5],
    'classifier__learning_rate': [0.12],
    'classifier__n_estimators': [500],
    'classifier__max_depth': [-1]
}

# Tối ưu mô hình
grid_search = GridSearchCV(pipeline, param_grid, cv=3, scoring='f1', n_jobs=-1, verbose=1, refit=True)
grid_search.fit(X_train, y_train)

# Lấy mô hình tốt nhất
best_model = grid_search.best_estimator_
print("Best parameters found:", grid_search.best_params_)

# Dự đoán trên tập validation
y_pred = best_model.predict(X_val)
f1 = f1_score(y_val, y_pred)
print(f'Optimized F1 Score: {f1:.4f}')

# Dự đoán trên tập test
test_predictions = best_model.predict(test_dt)

# Lưu mô hình
if isinstance(best_model, Pipeline):
    joblib.dump(best_model, 'trained_pipeline.pkl')
    print("🎉 Pipeline đã được lưu thành công vào trained_pipeline.pkl")
else:
    print("❌ LỖI: best_model không phải là pipeline!")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          8000 non-null   int64
#  1   ApplicationDate             8000 non-null   object
#  2   Age                         8000 non-null   int64
#  3   AnnualIncome                8000 non-null   int64
#  4   CreditScore                 8000 non-null   int64
#  5   EmploymentStatus            8000 non-null   object
#  6   EducationLevel              8000 non-null   object
#  7   Experience                  8000 non-null   int64
#  8   LoanAmount                  8000 non-null   int64
#  9   LoanDuration                8000 non-null   int64
#  10  MaritalStatus               8000 non-null   object
#  11  NumberOfDependents          8000 non-null   int64
#  12  HomeOwnershipStatus         8000 non-null   object
#  13  MonthlyDebtPayments         8000 non-null   int64
#  14  CreditCardUtilizationRate   8000 non-null   float64
#  15  NumberOfOpenCreditLines     8000 non-null   int64
#  16  NumberOfCreditInquiries     8000 non-null   int64
#  17  DebtToIncomeRatio           8000 non-null   float64
#  18  BankruptcyHistory           8000 non-null   int64
#  19  LoanPurpose                 8000 non-null   object
#  20  PreviousLoanDefaults        8000 non-null   int64
#  21  PaymentHistory              8000 non-null   int64
#  22  LengthOfCreditHistory       8000 non-null   int64
#  23  SavingsAccountBalance       8000 non-null   int64
#  24  CheckingAccountBalance      8000 non-null   int64
#  25  TotalAssets                 8000 non-null   int64
#  26  TotalLiabilities            8000 non-null   int64
#  27  MonthlyIncome               8000 non-null   float64
#  28  UtilityBillsPaymentHistory  8000 non-null   float64
#  29  JobTenure                   8000 non-null   int64
#  30  NetWorth                    8000 non-null   int64
#  31  BaseInterestRate            8000 non-null   float64
#  32  InterestRate                8000 non-null   float64
#  33  MonthlyLoanPayment          8000 non-null   float64
#  34  TotalDebtToIncomeRatio      8000 non-null   float64
#  35  LoanApproved                8000 non-null   int64
# dtypes: float64(8), int64(22), object(6)
# memory usage: 2.2+ MB
# None
#                ID          Age   AnnualIncome  CreditScore  Experience  \
# count  8000.00000  8000.000000    8000.000000  8000.000000  8000.00000
# mean   4000.50000    39.644250   59713.674125   571.547250    17.41500
# std    2309.54541    11.684702   41270.910819    51.479083    11.35659
# min       1.00000    18.000000   15000.000000   343.000000     0.00000
# 25%    2000.75000    31.000000   31523.750000   539.000000     9.00000
# 50%    4000.50000    39.000000   48707.500000   578.000000    17.00000
# 75%    6000.25000    48.000000   75100.250000   609.000000    25.00000
# max    8000.00000    80.000000  422480.000000   703.000000    61.00000
#
#           LoanAmount  LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count    8000.000000    8000.00000         8000.000000          8000.000000
# mean    24901.759875      53.86800            1.518250           451.198875
# std     13642.953309      24.75074            1.396392           236.367151
# min      3729.000000      12.00000            0.000000            65.000000
# 25%     15567.500000      36.00000            0.000000           285.000000
# 50%     21904.500000      48.00000            1.000000           400.000000
# 75%     30774.250000      60.00000            3.000000           558.000000
# max    184732.000000     120.00000            5.000000          2390.000000
#
#        CreditCardUtilizationRate  ...  TotalLiabilities  MonthlyIncome  \
# count                8000.000000  ...       8000.000000    8000.000000
# mean                    0.283938  ...      35952.206750    4937.183677
# std                     0.158737  ...      44895.042809    3367.797217
# min                     0.002672  ...        372.000000    1250.000000
# 25%                     0.160335  ...      11006.000000    2620.333333
# 50%                     0.265239  ...      22046.000000    4044.375000
# 75%                     0.388393  ...      43202.500000    6212.666667
# max                     0.871501  ...     682492.000000   25000.000000
#
#        UtilityBillsPaymentHistory    JobTenure      NetWorth  \
# count                 8000.000000  8000.000000  8.000000e+03
# mean                     0.798238     5.023000  7.280772e+04
# std                      0.120529     2.215476  1.195369e+05
# min                      0.276566     0.000000  1.004000e+03
# 25%                      0.724806     3.000000  8.698000e+03
# 50%                      0.818068     5.000000  3.313250e+04
# 75%                      0.891166     6.000000  8.957800e+04
# max                      0.998618    15.000000  2.603208e+06
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# count       8000.000000   8000.000000         8000.000000
# mean           0.239018      0.238994          916.425520
# std            0.035598      0.041946          682.637568
# min            0.144152      0.133880           97.030193
# 25%            0.213493      0.209428          490.516830
# 50%            0.235916      0.235181          729.700388
# 75%            0.261456      0.265610         1120.360816
# max            0.391126      0.446787        10892.629520
#
#        TotalDebtToIncomeRatio  LoanApproved
# count             8000.000000   8000.000000
# mean                 0.403581      0.243125
# std                  0.343218      0.428997
# min                  0.024642      0.000000
# 25%                  0.177332      0.000000
# 50%                  0.300108      0.000000
# 75%                  0.509985      0.000000
# max                  4.143180      1.000000
#
# [8 rows x 30 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 35 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          2000 non-null   int64
#  1   ApplicationDate             2000 non-null   object
#  2   Age                         2000 non-null   int64
#  3   AnnualIncome                2000 non-null   int64
#  4   CreditScore                 2000 non-null   int64
#  5   EmploymentStatus            2000 non-null   object
#  6   EducationLevel              2000 non-null   object
#  7   Experience                  2000 non-null   int64
#  8   LoanAmount                  2000 non-null   int64
#  9   LoanDuration                2000 non-null   int64
#  10  MaritalStatus               2000 non-null   object
#  11  NumberOfDependents          2000 non-null   int64
#  12  HomeOwnershipStatus         2000 non-null   object
#  13  MonthlyDebtPayments         2000 non-null   int64
#  14  CreditCardUtilizationRate   2000 non-null   float64
#  15  NumberOfOpenCreditLines     2000 non-null   int64
#  16  NumberOfCreditInquiries     2000 non-null   int64
#  17  DebtToIncomeRatio           2000 non-null   float64
#  18  BankruptcyHistory           2000 non-null   int64
#  19  LoanPurpose                 2000 non-null   object
#  20  PreviousLoanDefaults        2000 non-null   int64
#  21  PaymentHistory              2000 non-null   int64
#  22  LengthOfCreditHistory       2000 non-null   int64
#  23  SavingsAccountBalance       2000 non-null   int64
#  24  CheckingAccountBalance      2000 non-null   int64
#  25  TotalAssets                 2000 non-null   int64
#  26  TotalLiabilities            2000 non-null   int64
#  27  MonthlyIncome               2000 non-null   float64
#  28  UtilityBillsPaymentHistory  2000 non-null   float64
#  29  JobTenure                   2000 non-null   int64
#  30  NetWorth                    2000 non-null   int64
#  31  BaseInterestRate            2000 non-null   float64
#  32  InterestRate                2000 non-null   float64
#  33  MonthlyLoanPayment          2000 non-null   float64
#  34  TotalDebtToIncomeRatio      2000 non-null   float64
# dtypes: float64(8), int64(21), object(6)
# memory usage: 547.0+ KB
# None
#                  ID          Age   AnnualIncome  CreditScore  Experience  \
# count   2000.000000  2000.000000    2000.000000  2000.000000  2000.00000
# mean    9000.500000    39.693500   59360.951500   572.804000    17.52350
# std      577.494589    11.491283   38977.552222    49.612511    11.14251
# min     8001.000000    18.000000   15000.000000   362.000000     0.00000
# 25%     8500.750000    32.000000   32642.250000   544.000000     9.00000
# 50%     9000.500000    40.000000   49018.500000   579.000000    17.00000
# 75%     9500.250000    47.000000   75027.500000   609.000000    25.00000
# max    10000.000000    80.000000  300000.000000   707.000000    59.00000
#
#           LoanAmount  LoanDuration  NumberOfDependents  MonthlyDebtPayments  \
# count    2000.000000   2000.000000         2000.000000          2000.000000
# mean    24977.435000     54.858000            1.586000           456.573500
# std     12908.563906     25.068427            1.388369           245.013213
# min      4319.000000     12.000000            0.000000            83.000000
# 25%     15950.250000     36.000000            0.000000           283.000000
# 50%     22257.500000     48.000000            1.000000           401.500000
# 75%     31164.750000     72.000000            3.000000           571.000000
# max    105872.000000    120.000000            5.000000          1676.000000
#
#        CreditCardUtilizationRate  ...   TotalAssets  TotalLiabilities  \
# count                2000.000000  ...  2.000000e+03      2.000000e+03
# mean                    0.288408  ...  9.760982e+04      3.776865e+04
# std                     0.156520  ...  1.307576e+05      5.293814e+04
# min                     0.000974  ...  3.629000e+03      7.430000e+02
# 25%                     0.165739  ...  3.028175e+04      1.111350e+04
# 50%                     0.271328  ...  5.945700e+04      2.205350e+04
# 75%                     0.391718  ...  1.178100e+05      4.414125e+04
# max                     0.917380  ...  2.131807e+06      1.020702e+06
#
#        MonthlyIncome  UtilityBillsPaymentHistory    JobTenure      NetWorth  \
# count    2000.000000                 2000.000000  2000.000000  2.000000e+03
# mean     4909.834458                    0.805515     4.960000  7.265030e+04
# std      3199.648327                    0.119680     2.280351  1.268754e+05
# min      1250.000000                    0.284422     0.000000  1.030000e+03
# 25%      2714.854167                    0.737812     3.000000  8.503000e+03
# 50%      4078.541667                    0.828262     5.000000  3.184450e+04
# 75%      6214.645833                    0.895264     6.000000  8.602300e+04
# max     25000.000000                    0.996897    14.000000  2.106873e+06
#
#        BaseInterestRate  InterestRate  MonthlyLoanPayment  \
# count       2000.000000   2000.000000         2000.000000
# mean           0.239290      0.240136          918.817066
# std            0.034612      0.042603          667.937331
# min            0.135055      0.131954          118.390603
# 25%            0.214548      0.209819          490.456918
# 50%            0.236631      0.236155          741.160463
# 75%            0.261774      0.266572         1120.446941
# max            0.389320      0.402834         5571.130435
#
#        TotalDebtToIncomeRatio
# count             2000.000000
# mean                 0.398759
# std                  0.332359
# min                  0.016043
# 25%                  0.177639
# 50%                  0.299475
# 75%                  0.500213
# max                  2.917662
#
# [8 rows x 29 columns]
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Info] Number of positive: 1550, number of negative: 4850
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000555 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4841
# [LightGBM] [Info] Number of data points in the train set: 6400, number of used features: 71
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.242188 -> initscore=-1.140724
# [LightGBM] [Info] Start training from score -1.140724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best parameters found: {'classifier__learning_rate': 0.12, 'classifier__max_depth': -1, 'classifier__min_data_in_leaf': 5, 'classifier__n_estimators': 500, 'classifier__num_leaves': 31}
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# Optimized F1 Score: 0.8972
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# 🎉 Pipeline đã được lưu thành công vào trained_pipeline.pkl
# c:\Apps\miniconda3forpython\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# c:\Apps\miniconda3forpython\envs\myenv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
